# %%
from pdf_data_extractor import PDFReader, clean_text, text_to_dataframe, visualize_text_and_tables

# Initialize the PDFReader
reader = PDFReader("C:\Andriy\.SPL\РГР\student_part_time_job_impact1.pdf")

# Extract text
text_data = reader.extract_text()

# Convert text to DataFrame
df = text_to_dataframe(text_data)
df = df.drop_duplicates().drop(0)

# Display the DataFrame
display(df)
# Out:
# c:\Andriy\.PKR\Anaconda2\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#     Student_ID                         Date Work_Hours            Job_Type  \
# 1        S0001   2024-09-27 06:38:25.228722         28    Retail Assistant
# 2        S0002   2024-05-15 06:38:25.228722         40  Research Assistant
# 3        S0003   2024-04-23 06:38:25.228722         18    Retail Assistant
# 4        S0004   2024-06-26 06:38:25.228722         11               Tutor
# 5        S0005   2024-06-18 06:38:25.228722         13          Freelancer
# ..         ...                          ...        ...                 ...
# 496      S0496   2024-07-10 06:38:25.228722         24               Tutor
# 497      S0497   2024-04-24 06:38:25.228722         35    Retail Assistant
# 498      S0498   2024-05-16 06:38:25.228722         10    Retail Assistant
# ...

# %%
# Visualize text and tables on a page
visualize_text_and_tables(reader, 0)

# %%
# File statistic example
pdf_reader = PDFReader("C:\Andriy\.SPL\РГР\student_part_time_job_impact1.pdf")
stats = pdf_reader.get_file_statistics()
print("PDF File Statistics:")
for key, value in stats.items():
   # Replace underscores with spaces and capitalize each word
   formatted_key = key.replace("_", " ").capitalize()
   print(f"{formatted_key}: {value}")
# Out:
# PDF File Statistics:
# Page count: 12
# Total words: 1208
# Total characters: 33615
# Average words per page: 100.66666666666667
# Average characters per page: 2801.25

# %%
# Language statistic example
pdf_reader = PDFReader("C:/Users/Андрій/Downloads/БА_дз_лек4.pdf")
language_stats = pdf_reader.get_language_statistics()

print("Language Statistics:")
for lang, percentage in language_stats.items():
   print(f"{lang}: {percentage}%")
# Out:
# Language Statistics:
# uk: 50.0%
# ca: 50.0%
